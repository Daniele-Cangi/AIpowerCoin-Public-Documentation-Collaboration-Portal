# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniele-Cangi/AIpowerCoin-Public-Documentation-Collaboration-Portal/blob/main/NEXUS_TRANSFER_64_ANCHORS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📝 NEXUS_TRANSFER_64_ANCHORS.ipynb
# -------------------------------------------------------------
# 🚀 NEXUS Transfer Learning - 64 Anchors Edition
# ✅ Checkpoint ogni 2000 steps
# ✅ 64 NSA anchors (vs 32 original)
# ✅ Analisi anchor specialization post-training
# -------------------------------------------------------------
# STEP 0: MOUNT GOOGLE DRIVE & SETUP CHECKPOINT DIR
from google.colab import drive
import os

drive.mount('/content/drive')
CHECKPOINT_DIR = '/content/drive/MyDrive/nexus_checkpoints_64anchors'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
print(f"✅ Google Drive montato! -> {CHECKPOINT_DIR}")
print("⚠️ I checkpoint sopravvivono ai disconnect di Colab.")
# Out:
# Mounted at /content/drive
# ✅ Google Drive montato! -> /content/drive/MyDrive/nexus_checkpoints_64anchors
# ⚠️ I checkpoint sopravvivono ai disconnect di Colab.

# %%
# STEP 1: SETUP AMBIENTE (Re-eseguibile)
# !pip -q install torch transformers datasets tqdm sentencepiece accelerate
import torch, platform
print(f"Torch: {torch.__version__} | Python: {platform.python_version()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} | VRAM: {torch.cuda.get_device_properties(0).total_memory/1024**3:.1f} GB")
else:
    print("⚠️ No CUDA detected")
# Out:
# Torch: 2.8.0+cu126 | Python: 3.12.11
# GPU: NVIDIA A100-SXM4-40GB | VRAM: 39.6 GB

# %%
# STEP 2: DOWNLOAD MICROSOFT ALLNLI DATASET
from datasets import load_dataset
import json
from tqdm import tqdm

print("📥 Downloading Microsoft AllNLI dataset...")

# Download AllNLI (combines SNLI + MultiNLI)
try:
    # Load SNLI dataset
    snli = load_dataset("snli", split="train")
    print(f"✅ SNLI loaded: {len(snli):,} examples")

    # Load MultiNLI dataset
    mnli = load_dataset("multi_nli", split="train")
    print(f"✅ MultiNLI loaded: {len(mnli):,} examples")

    # Filter out examples with label -1 (unlabeled) and combine
    all_data = []

    # Process SNLI
    for item in tqdm(snli, desc="Processing SNLI"):
        if item['label'] != -1:  # Skip unlabeled
            all_data.append({
                'sentence1': item['premise'],
                'sentence2': item['hypothesis'],
                'label': ['entailment', 'neutral', 'contradiction'][item['label']]
            })

    # Process MultiNLI
    for item in tqdm(mnli, desc="Processing MultiNLI"):
        if item['label'] != -1:  # Skip unlabeled
            all_data.append({
                'sentence1': item['premise'],
                'sentence2': item['hypothesis'],
                'label': ['entailment', 'neutral', 'contradiction'][item['label']]
            })

    # Save to JSONL for PairDataset
    with open('/content/allnli_pairs.jsonl', 'w') as f:
        for item in all_data:
            f.write(json.dumps(item) + '\n')

    print(f"✅ AllNLI dataset ready: {len(all_data):,} examples")
    print(f"📁 Saved to: /content/allnli_pairs.jsonl")

except Exception as e:
    print(f"❌ Error downloading dataset: {e}")
    print("📝 Creating minimal demo dataset for testing...")

    # Fallback demo data with correct format
    demo_data = [
        {"sentence1": "A person on a horse jumps over a broken down airplane.", "sentence2": "A person is at a diner, ordering an omelette.", "label": "contradiction"},
        {"sentence1": "Children smiling and waving at camera", "sentence2": "They are smiling at a camera", "label": "entailment"},
        {"sentence1": "A black race car starts up in front of a crowd of people.", "sentence2": "A man is driving down a lonely road.", "label": "contradiction"},
        {"sentence1": "Two women are embracing while holding to go packages.", "sentence2": "Two women are holding packages.", "label": "entailment"},
        {"sentence1": "A soccer game with multiple males playing.", "sentence2": "Some men are playing a sport.", "label": "entailment"}
    ] * 1000  # Repeat for testing

    with open('/content/allnli_pairs.jsonl', 'w') as f:
        for item in demo_data:
            f.write(json.dumps(item) + '\n')

    print(f"✅ Demo dataset created: {len(demo_data):,} examples")
# Out:
# 📥 Downloading Microsoft AllNLI dataset...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# plain_text/test-00000-of-00001.parquet:   0%|          | 0.00/412k [00:00<?, ?B/s]
# plain_text/validation-00000-of-00001.par(…):   0%|          | 0.00/413k [00:00<?, ?B/s]
# plain_text/train-00000-of-00001.parquet:   0%|          | 0.00/19.6M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/550152 [00:00<?, ? examples/s]
# ✅ SNLI loaded: 550,152 examples
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/214M [00:00<?, ?B/s]
# data/validation_matched-00000-of-00001.p(…):   0%|          | 0.00/4.94M [00:00<?, ?B/s]
# data/validation_mismatched-00000-of-0000(…):   0%|          | 0.00/5.10M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/392702 [00:00<?, ? examples/s]
# Generating validation_matched split:   0%|          | 0/9815 [00:00<?, ? examples/s]
# Generating validation_mismatched split:   0%|          | 0/9832 [00:00<?, ? examples/s]
# ✅ MultiNLI loaded: 392,702 examples
# Processing SNLI: 100%|██████████| 550152/550152 [00:17<00:00, 30688.44it/s]
# Processing MultiNLI: 100%|██████████| 392702/392702 [00:35<00:00, 11215.43it/s]
# ✅ AllNLI dataset ready: 942,069 examples
# 📁 Saved to: /content/allnli_pairs.jsonl

# %%
# STEP 3: MODEL + LOSS DEFINITIONS
import torch, torch.nn as nn, torch.nn.functional as F, numpy as np, random
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer
import math, json

class NexusTransfer(nn.Module):
    def __init__(self, base_model_name='microsoft/mpnet-base', num_topics=3, hash_dim=256, nsa_anchors=64):
        super().__init__()
        self.base = AutoModel.from_pretrained(base_model_name)
        d = self.base.config.hidden_size
        self.topic_head = nn.Linear(d, num_topics)
        self.hash_proj = nn.Linear(d, hash_dim)
        self.anchors = nn.Parameter(torch.randn(nsa_anchors, d))
        print(f"✅ Base {base_model_name} | Params {sum(p.numel() for p in self.parameters()):,}")
    def forward(self, input_ids, attention_mask=None):
        out = self.base(input_ids=input_ids, attention_mask=attention_mask)
        h = out.last_hidden_state
        if attention_mask is not None:
            mask = attention_mask.unsqueeze(-1).float()
            h = (h * mask).sum(1) / mask.sum(1).clamp(min=1e-9)
        else:
            h = h.mean(1)
        emb = F.normalize(h, dim=-1)
        topic_logits = self.topic_head(emb)
        hash_emb = torch.tanh(self.hash_proj(emb))
        nsa_scores = emb @ self.anchors.T
        return emb, topic_logits, hash_emb, nsa_scores

class PairDataset(Dataset):
    def __init__(self, path):
        with open(path,'r',encoding='utf-8') as f:
            self.data = [json.loads(l) for l in f]
        # Map labels to integers for topic classification
        self.label_map = {'entailment': 0, 'neutral': 1, 'contradiction': 2}
    def __len__(self): return len(self.data)
    def __getitem__(self,i):
        d = self.data[i]
        return d['sentence1'], d['sentence2'], self.label_map[d['label']]

def info_nce(a,b,t=0.07):
    sim = a @ b.T / t
    labels = torch.arange(sim.size(0), device=sim.device)
    return (F.cross_entropy(sim, labels) + F.cross_entropy(sim.T, labels)) / 2

def matryoshka_loss(a,b,dims,t=0.07):
    return sum(info_nce(F.normalize(a[:,:d],dim=-1), F.normalize(b[:,:d],dim=-1), t) for d in dims)/len(dims)

def hash_loss(h):
    return ((h - h.sign())**2).mean()

def spec_loss(scores_a, scores_b):
    return 1.0 - (F.normalize(scores_a,dim=-1)*F.normalize(scores_b,dim=-1)).sum(-1).mean()

# %%
# STEP 4: INIT MODEL + DATA + OPTIMIZER
import torch, time
from torch.cuda.amp import GradScaler, autocast

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', device)

tokenizer = AutoTokenizer.from_pretrained('microsoft/mpnet-base')
model = NexusTransfer(nsa_anchors=64).to(device)
try:
    model = torch.compile(model, mode='max-autotune')
    print('torch.compile enabled')
except Exception as e:
    print('compile skipped:', e)

ds = PairDataset('/content/allnli_pairs.jsonl')
print(f'Dataset size: {len(ds):,}')

BATCH=64; MAX_LEN=128; DIMS=[768,512,384,256,128]; TEMP=0.07

def collate(batch):
    A,B,T = zip(*batch)
    enc_a = tokenizer(list(A), padding=True, truncation=True, max_length=MAX_LEN, return_tensors='pt')
    enc_b = tokenizer(list(B), padding=True, truncation=True, max_length=MAX_LEN, return_tensors='pt')
    return enc_a['input_ids'], enc_a['attention_mask'], enc_b['input_ids'], enc_b['attention_mask'], torch.tensor(T)

dl = DataLoader(ds, batch_size=BATCH, shuffle=True, drop_last=True, collate_fn=collate)

base_params = list(model._orig_mod.base.parameters()) if hasattr(model,'_orig_mod') else list(model.base.parameters())
heads = [p for n,p in model.named_parameters() if 'base.' not in n]
opt = torch.optim.AdamW([
    {'params': base_params, 'lr': 2e-5},
    {'params': heads, 'lr': 1e-4}
], weight_decay=0.01, fused=True)
scaler = GradScaler()

start_step = 0
latest_ptr = f"{CHECKPOINT_DIR}/latest_checkpoint.txt"
if os.path.exists(latest_ptr):
    try:
        with open(latest_ptr) as f: ckpt_path = f.read().strip()
        ckpt = torch.load(ckpt_path)
        state = ckpt['model']
        if any(k.startswith('_orig_mod.') for k in state):
            state = {k.replace('_orig_mod.',''):v for k,v in state.items()}
            (model._orig_mod if hasattr(model,'_orig_mod') else model).load_state_dict(state)
        else:
            (model._orig_mod if hasattr(model,'_orig_mod') else model).load_state_dict(state)
        opt.load_state_dict(ckpt['opt'])
        start_step = ckpt['step']
        print('Resumed from', ckpt_path, 'step', start_step)
    except Exception as e:
        print('Resume failed:', e)
# Out:
# Device: cuda
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/493 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/532M [00:00<?, ?B/s]
# Some weights of MPNetModel were not initialized from the model checkpoint at microsoft/mpnet-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Base microsoft/mpnet-base | Params 109,734,787
# torch.compile enabled
# Dataset size: 942,069
# /tmp/ipython-input-472773170.py:35: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Resumed from /content/drive/MyDrive/nexus_checkpoints_64anchors/ckpt_30000.pt step 30000

# %%
# STEP 5: TRAINING LOOP (checkpoint ogni 2000 step)
TOTAL_STEPS = 30000
CKPT_INTERVAL = 2000
step = start_step
model.train(); opt.zero_grad(set_to_none=True)
start_time = time.time()
for epoch in range(999999):
    for a_ids, a_mask, b_ids, b_mask, topics in dl:
        a_ids=a_ids.to(device); a_mask=a_mask.to(device); b_ids=b_ids.to(device); b_mask=b_mask.to(device); topics=topics.to(device)
        with autocast():
            emb_a, logit_a, hash_a, spec_a = model(a_ids, a_mask)
            emb_b, logit_b, hash_b, spec_b = model(b_ids, b_mask)
            L_main = matryoshka_loss(emb_a, emb_b, DIMS, t=TEMP)
            L_topic = 0.03 * F.cross_entropy(logit_a, topics)
            L_hash = 0.01 * hash_loss(hash_a)
            L_spec = 0.03 * spec_loss(spec_a, spec_b)
            loss = L_main + L_topic + L_hash + L_spec
        scaler.scale(loss).backward()
        scaler.unscale_(opt)
        torch.nn.utils.clip_grad_norm_(model.parameters(),1.0)
        scaler.step(opt); scaler.update(); opt.zero_grad(set_to_none=True)
        step += 1
        if step % 100 == 0:
            elapsed = (time.time()-start_time)/3600
            speed = (step-start_step)/elapsed if elapsed>0 else 0
            print(f"Step {step:,} | Loss {loss.item():.4f} | M {L_main.item():.3f} T {L_topic.item():.3f} H {L_hash.item():.3f} S {L_spec.item():.3f} | {speed:.0f} st/h")
        if step % CKPT_INTERVAL == 0:
            raw = model._orig_mod if hasattr(model,'_orig_mod') else model
            ckpt_path = f"{CHECKPOINT_DIR}/ckpt_{step}.pt"
            torch.save({'step': step, 'model': raw.state_dict(), 'opt': opt.state_dict()}, ckpt_path)
            with open(f"{CHECKPOINT_DIR}/latest_checkpoint.txt","w") as f: f.write(ckpt_path)
            print('💾 Saved', ckpt_path)
        if step >= TOTAL_STEPS:
            break
    if step >= TOTAL_STEPS:
        break
print('✅ Training complete. Total steps:', step)
# Out:
# /tmp/ipython-input-860931953.py:10: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# AUTOTUNE addmm(4352x3072, 4352x768, 768x3072)
# strides: [0, 1], [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16, torch.float16
#   triton_mm_130 0.1085 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_129 0.1167 ms 93.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_122 0.1208 ms 89.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_126 0.1208 ms 89.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_124 0.1239 ms 87.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_131 0.1249 ms 86.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   bias_addmm 0.1270 ms 85.5%
#   triton_mm_123 0.1454 ms 74.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_127 0.1454 ms 74.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_119 0.1638 ms 66.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.6791 seconds and 0.0005 seconds precompiling for 21 choices
# AUTOTUNE mm(64x768, 768x256)
# strides: [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16
#   mm 0.0092 ms 100.0%
#   triton_mm_1828 0.0123 ms 75.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1836 0.0133 ms 69.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_1838 0.0133 ms 69.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_1825 0.0143 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_1826 0.0143 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1827 0.0143 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1832 0.0143 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1840 0.0143 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1831 0.0154 ms 60.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.3100 seconds and 0.0003 seconds precompiling for 18 choices
# AUTOTUNE mm(4352x768, 768x768)
# strides: [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16
#   triton_mm_17 0.0328 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_16 0.0348 ms 94.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_9 0.0358 ms 91.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_11 0.0358 ms 91.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_13 0.0358 ms 91.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_18 0.0358 ms 91.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   mm 0.0389 ms 84.2%
#   triton_mm_10 0.0410 ms 80.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_14 0.0410 ms 80.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_15 0.0420 ms 78.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.4062 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE bmm(768x68x64, 768x64x68)
# strides: [4352, 64, 1], [4352, 68, 1]
# dtypes: torch.float16, torch.float16
#   triton_bmm_68 0.0266 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_69 0.0276 ms 96.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_75 0.0276 ms 96.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_bmm_74 0.0297 ms 89.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_64 0.0307 ms 86.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_bmm_65 0.0307 ms 86.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_73 0.0307 ms 86.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_58 0.0317 ms 83.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_72 0.0317 ms 83.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=8
#   triton_bmm_61 0.0328 ms 81.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3355 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE bmm(768x68x68, 768x68x64)
# strides: [4672, 68, 1], [4352, 64, 1]
# dtypes: torch.float16, torch.float16
#   triton_bmm_84 0.0287 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_88 0.0287 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_90 0.0297 ms 96.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_85 0.0307 ms 93.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_89 0.0307 ms 93.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_78 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_bmm_82 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_83 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_bmm_86 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_87 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3285 seconds and 0.0004 seconds precompiling for 19 choices
# AUTOTUNE mm(4352x3072, 3072x768)
# strides: [3072, 1], [1, 3072]
# dtypes: torch.float16, torch.float16
#   triton_mm_149 0.0942 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   mm 0.1004 ms 93.9%
#   triton_mm_148 0.1065 ms 88.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_143 0.1126 ms 83.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_145 0.1137 ms 82.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_150 0.1208 ms 78.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_144 0.1290 ms 73.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_141 0.1352 ms 69.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_142 0.1352 ms 69.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_146 0.1362 ms 69.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.6120 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE addmm(64x8, 64x768, 768x8)
# strides: [0, 1], [768, 1], [8, 1]
# dtypes: torch.float16, torch.float16, torch.float16
#   triton_mm_1816 0.0092 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1822 0.0092 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_1823 0.0092 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1814 0.0102 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   triton_mm_1815 0.0102 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1813 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=2
#   triton_mm_1819 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1821 0.0123 ms 75.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   addmm 0.0133 ms 69.2%
#   triton_mm_1820 0.0143 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=16, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.2451 seconds and 0.0003 seconds precompiling for 14 choices
# AUTOTUNE mm(64x768, 768x64)
# strides: [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16
#   mm 0.0092 ms 100.0%
#   triton_mm_1845 0.0102 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1842 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_1843 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1844 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1849 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_1853 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_1855 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1848 0.0123 ms 75.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_1852 0.0123 ms 75.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.2744 seconds and 0.0003 seconds precompiling for 16 choices
# AUTOTUNE addmm(1472x3072, 1472x768, 768x3072)
# strides: [0, 1], [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16, torch.float16
#   triton_mm_1970 0.0481 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1971 0.0481 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1963 0.0512 ms 94.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1965 0.0512 ms 94.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   bias_addmm 0.0532 ms 90.4%
#   triton_mm_1972 0.0532 ms 90.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1967 0.0543 ms 88.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1964 0.0594 ms 81.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_1968 0.0594 ms 81.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_1966 0.0655 ms 73.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.4882 seconds and 0.0004 seconds precompiling for 21 choices
# AUTOTUNE mm(1472x768, 768x768)
# strides: [768, 1], [1, 768]
# dtypes: torch.float16, torch.float16
#   triton_mm_1874 0.0195 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1873 0.0205 ms 95.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1872 0.0236 ms 82.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   mm 0.0246 ms 79.2%
#   triton_mm_1867 0.0256 ms 76.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1865 0.0276 ms 70.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1863 0.0287 ms 67.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_1869 0.0287 ms 67.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1866 0.0297 ms 65.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_1868 0.0317 ms 61.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3535 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE bmm(768x23x64, 768x64x23)
# strides: [64*s53, 64, 1], [64*s53, s53, 1]
# dtypes: torch.float16, torch.float16
#   triton_bmm_1913 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=1, num_warps=2
#   triton_bmm_1914 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_1915 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_1916 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_1918 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_1919 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_1920 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_1921 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_1922 0.0133 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   bmm 0.0154 ms 86.7%
# SingleProcess AUTOTUNE benchmarking takes 0.1811 seconds and 0.0003 seconds precompiling for 11 choices
# AUTOTUNE bmm(768x23x23, 768x23x64)
# strides: [s53**2, s53, 1], [64*s53, 64, 1]
# dtypes: torch.float16, torch.float16
#   triton_bmm_1927 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_1928 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_1930 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_1931 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_1933 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_1923 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=1, num_warps=2
#   triton_bmm_1924 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_1925 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_bmm_1926 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_1929 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.2141 seconds and 0.0003 seconds precompiling for 13 choices
# AUTOTUNE mm(1472x3072, 3072x768)
# strides: [3072, 1], [1, 3072]
# dtypes: torch.float16, torch.float16
#   mm 0.0461 ms 100.0%
#   triton_mm_1984 0.0594 ms 77.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1990 0.0594 ms 77.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1991 0.0594 ms 77.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_1980 0.0614 ms 75.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_1982 0.0666 ms 69.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1983 0.0686 ms 67.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_1986 0.0686 ms 67.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_1985 0.0696 ms 66.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_1987 0.0696 ms 66.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.4374 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(1472x768, 768x3072)
# strides: [768, 1], [3072, 1]
# dtypes: torch.float16, torch.float16
#   triton_mm_3651 0.0440 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3643 0.0471 ms 93.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3652 0.0502 ms 87.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3645 0.0512 ms 86.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3650 0.0512 ms 86.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   mm 0.0532 ms 82.7%
#   triton_mm_3644 0.0543 ms 81.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3647 0.0543 ms 81.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3648 0.0543 ms 81.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3646 0.0594 ms 74.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.4457 seconds and 0.0005 seconds precompiling for 20 choices
# AUTOTUNE mm(768x1472, 1472x3072)
# strides: [1, 768], [3072, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0451 ms 100.0%
#   triton_mm_3662 0.0471 ms 95.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3664 0.0471 ms 95.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3666 0.0481 ms 93.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3667 0.0502 ms 89.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3669 0.0512 ms 88.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3670 0.0522 ms 86.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3663 0.0532 ms 84.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3659 0.0614 ms 73.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3660 0.0614 ms 73.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.4172 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(3072x1472, 1472x768)
# strides: [1, 3072], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0451 ms 100.0%
#   triton_mm_3702 0.0471 ms 95.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3704 0.0471 ms 95.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3700 0.0481 ms 93.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3705 0.0502 ms 89.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3707 0.0522 ms 86.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3701 0.0532 ms 84.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3708 0.0563 ms 80.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3697 0.0614 ms 73.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3698 0.0614 ms 73.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.4203 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(768x1472, 1472x768)
# strides: [1, 768], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0195 ms 100.0%
#   triton_mm_3743 0.0246 ms 79.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3736 0.0266 ms 73.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3737 0.0276 ms 70.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3741 0.0276 ms 70.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_3740 0.0297 ms 65.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3742 0.0307 ms 63.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3746 0.0307 ms 63.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3733 0.0317 ms 61.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=32, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3739 0.0328 ms 59.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.3754 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(256x64, 64x768)
# strides: [1, 256], [768, 1]
# dtypes: torch.float16, torch.float16
#   triton_mm_3584 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3585 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3586 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3587 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3590 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3591 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3592 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3594 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3596 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   mm 0.0082 ms 87.5%
# SingleProcess AUTOTUNE benchmarking takes 0.3328 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(3x64, 64x768)
# strides: [1, 3], [768, 1]
# dtypes: torch.float16, torch.float16
#   triton_mm_3618 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=2
#   triton_mm_3619 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3620 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   triton_mm_3621 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=2
#   triton_mm_3623 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3624 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3625 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3626 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3627 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3628 0.0072 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=16, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3003 seconds and 0.0003 seconds precompiling for 18 choices
# AUTOTUNE mm(64x64, 64x768)
# strides: [1, 64], [768, 1]
# dtypes: torch.float16, torch.float16
#   triton_mm_3533 0.0061 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3534 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3535 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3536 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3538 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3539 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3540 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3544 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_3545 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3546 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.2930 seconds and 0.0003 seconds precompiling for 18 choices
# AUTOTUNE mm(64x64, 64x768)
# strides: [64, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   triton_mm_3550 0.0061 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   mm 0.0072 ms 85.7%
#   triton_mm_3551 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3552 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3553 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3556 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3557 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3559 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3561 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_3562 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 1.3498 seconds and 0.0003 seconds precompiling for 18 choices
# AUTOTUNE mm(64x256, 256x768)
# strides: [256, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0082 ms 100.0%
#   triton_mm_3567 0.0082 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_3568 0.0082 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3570 0.0082 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3574 0.0082 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3569 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3573 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3577 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3580 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3575 0.0102 ms 80.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.2972 seconds and 0.0005 seconds precompiling for 18 choices
# AUTOTUNE mm(64x3, 3x768)
# strides: [3, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   triton_mm_3613 0.0061 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3614 0.0061 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3615 0.0061 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=8
#   mm 0.0072 ms 85.7%
#   triton_mm_3602 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=1, num_warps=2
#   triton_mm_3610 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3611 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3612 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_3616 0.0072 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3609 0.0143 ms 42.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.2874 seconds and 0.0005 seconds precompiling for 16 choices
# AUTOTUNE mm(1472x3072, 3072x768)
# strides: [3072, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0451 ms 100.0%
#   triton_mm_3683 0.0584 ms 77.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3689 0.0604 ms 74.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3679 0.0635 ms 71.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3681 0.0635 ms 71.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3690 0.0635 ms 71.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3685 0.0655 ms 68.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3680 0.0666 ms 67.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_3684 0.0686 ms 65.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_3688 0.0686 ms 65.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.4347 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(1472x768, 768x768)
# strides: [768, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0184 ms 100.0%
#   triton_mm_3721 0.0205 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3727 0.0205 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3728 0.0205 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_3719 0.0215 ms 85.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3717 0.0225 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_3723 0.0225 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_3720 0.0236 ms 78.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3724 0.0236 ms 78.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_3726 0.0236 ms 78.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3336 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE bmm(768x23x23, 768x23x64)
# strides: [s53**2, 1, s53], [64*s53, 64, 1]
# ...
# SingleProcess AUTOTUNE benchmarking takes 0.6132 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(3072x4352, 4352x768)
# strides: [1, 3072], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0901 ms 100.0%
#   triton_mm_7090 0.1126 ms 80.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7092 0.1147 ms 78.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7094 0.1198 ms 75.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7098 0.1311 ms 68.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7095 0.1331 ms 67.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7093 0.1382 ms 65.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_7097 0.1382 ms 65.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7091 0.1454 ms 62.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7089 0.1577 ms 57.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.6137 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(768x4352, 4352x768)
# strides: [1, 768], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0348 ms 100.0%
#   triton_mm_7131 0.0502 ms 69.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_7130 0.0553 ms 63.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7127 0.0563 ms 61.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_mm_7129 0.0614 ms 56.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7133 0.0614 ms 56.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7126 0.0625 ms 55.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_mm_7120 0.0758 ms 45.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_mm_7128 0.0758 ms 45.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7132 0.0758 ms 45.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.4386 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE mm(4352x3072, 3072x768)
# strides: [3072, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0881 ms 100.0%
#   triton_mm_7079 0.0942 ms 93.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7078 0.1014 ms 86.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7071 0.1096 ms 80.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7080 0.1096 ms 80.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_7075 0.1147 ms 76.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7073 0.1270 ms 69.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7074 0.1300 ms 67.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_mm_7076 0.1352 ms 65.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7072 0.1382 ms 63.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.5864 seconds and 0.0002 seconds precompiling for 20 choices
# AUTOTUNE mm(4352x768, 768x768)
# strides: [768, 1], [768, 1]
# dtypes: torch.float16, torch.float16
#   mm 0.0297 ms 100.0%
#   triton_mm_7117 0.0317 ms 93.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7116 0.0338 ms 87.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7109 0.0358 ms 82.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7111 0.0358 ms 82.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7113 0.0358 ms 82.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_mm_7118 0.0358 ms 82.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_mm_7110 0.0399 ms 74.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7114 0.0410 ms 72.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_mm_7115 0.0410 ms 72.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.3647 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE bmm(768x68x68, 768x68x64)
# strides: [4672, 1, 68], [4352, 64, 1]
# dtypes: torch.float16, torch.float16
#   triton_bmm_7146 0.0276 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_7150 0.0276 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_7151 0.0287 ms 96.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7152 0.0287 ms 96.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_7147 0.0297 ms 93.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7154 0.0297 ms 93.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7144 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_7148 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_7149 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7140 0.0317 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.3025 seconds and 0.0003 seconds precompiling for 19 choices
# AUTOTUNE bmm(768x68x64, 768x64x68)
# strides: [4352, 64, 1], [4352, 1, 64]
# dtypes: torch.float16, torch.float16
#   triton_bmm_7167 0.0276 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7168 0.0276 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_7174 0.0276 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=8
#   triton_bmm_7164 0.0287 ms 96.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_7173 0.0287 ms 96.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7160 0.0297 ms 93.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_7157 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_7163 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_bmm_7172 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7165 0.0317 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=True, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3188 seconds and 0.0003 seconds precompiling for 20 choices
# AUTOTUNE bmm(768x64x68, 768x68x68)
# strides: [4352, 1, 64], [4672, 68, 1]
# dtypes: torch.float16, torch.float16
#   triton_bmm_7187 0.0276 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=4
#   triton_bmm_7183 0.0287 ms 96.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_7184 0.0297 ms 93.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7185 0.0297 ms 93.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_7179 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=32, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
#   triton_bmm_7188 0.0307 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7180 0.0317 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_7181 0.0317 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_7186 0.0317 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=128, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7189 0.0317 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 0.2849 seconds and 0.0003 seconds precompiling for 18 choices
# AUTOTUNE bmm(768x72x72, 768x72x64)
# strides: [5184, 72, 1], [4608, 1, 72]
# dtypes: torch.float16, torch.float16
#   triton_bmm_7208 0.0287 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7203 0.0297 ms 96.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7205 0.0297 ms 96.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7206 0.0297 ms 96.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_7199 0.0307 ms 93.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=8
#   triton_bmm_7202 0.0307 ms 93.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=4, num_warps=8
#   triton_bmm_7198 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=4
#   triton_bmm_7201 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=3, num_warps=4
#   triton_bmm_7207 0.0317 ms 90.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=2, num_warps=8
#   triton_bmm_7200 0.0328 ms 87.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=64, EVEN_K=False, GROUP_M=8, USE_FAST_ACCUM=False, num_stages=5, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 0.3078 seconds and 0.0003 seconds precompiling for 19 choices
# ✅ Training complete. Total steps: 30001

# %%
# STEP 6: EVALUATION + SIMILARITY TESTS
import numpy as np, os, torch
latest_ptr = f"{CHECKPOINT_DIR}/latest_checkpoint.txt"
if not os.path.exists(latest_ptr):
    raise FileNotFoundError('No checkpoint to evaluate')
with open(latest_ptr) as f: ckpt_path = f.read().strip()
ckpt = torch.load(ckpt_path, map_location='cpu')
raw = NexusTransfer(nsa_anchors=64).to(device)
raw.load_state_dict(ckpt['model'])
raw.eval()

def embed(texts, batch_size=32):
    all_vecs = []
    for i in range(0,len(texts), batch_size):
        batch = texts[i:i+batch_size]
        enc = tokenizer(batch, padding=True, truncation=True, max_length=MAX_LEN, return_tensors='pt').to(device)
        with torch.no_grad():
            emb, *_ = raw(enc['input_ids'], enc.get('attention_mask'))
        all_vecs.append(emb.cpu())
    return torch.cat(all_vecs).numpy()

tests = [
 ("Bitcoin reaches new all-time high","BTC price surges",True),
 ("AI is advancing rapidly","Machine learning progresses",True),
 ("The cat sleeps on the sofa","A feline rests",True),
 ("Rome is the capital of Italy","Bitcoin price rises",False),
 ("Pizza is Italian food","Neural networks for AI",False)
]
pos, neg = [], []
for a,b,is_pos in tests:
    va, vb = embed([a])[0], embed([b])[0]
    sim = float(np.dot(va,vb))
    (pos if is_pos else neg).append(sim)
    badge = '✅' if (sim>0.65 and is_pos) or (sim<0.35 and not is_pos) else '⚠️'
    print(f"{badge} {a[:32]:32} <> {b[:32]:32} | {sim:.3f}")
print('\nAverages -> pos:', np.mean(pos), 'neg:', np.mean(neg), 'separation:', np.mean(pos)-np.mean(neg))
# Out:
# Some weights of MPNetModel were not initialized from the model checkpoint at microsoft/mpnet-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Base microsoft/mpnet-base | Params 109,734,787
# ✅ Bitcoin reaches new all-time hig <> BTC price surges                 | 0.720
# ⚠️ AI is advancing rapidly          <> Machine learning progresses      | 0.583
# ✅ The cat sleeps on the sofa       <> A feline rests                   | 0.778
# ✅ Rome is the capital of Italy     <> Bitcoin price rises              | 0.121
# ✅ Pizza is Italian food            <> Neural networks for AI           | 0.151
#
# Averages -> pos: 0.6933179299036661 neg: 0.13598528504371643 separation: 0.5573326448599497

# %%
# STEP 7: ANCHOR SPECIALIZATION + EXPORT
from tqdm import tqdm
import csv
raw.eval()

REPORT_TXT = f"{CHECKPOINT_DIR}/anchor_analysis.txt"
REPORT_CSV = f"{CHECKPOINT_DIR}/anchor_top.csv"

@torch.no_grad()
def analyze_anchors(sample_size=800):
    import random
    sample_size = min(sample_size, len(ds))
    idxs = random.sample(range(len(ds)), sample_size)
    activations = {i: [] for i in range(raw.anchors.shape[0])}
    for i in tqdm(idxs, desc='Anchors'):
        a,b,_ = ds[i]
        enc = tokenizer([a], padding=True, truncation=True, max_length=MAX_LEN, return_tensors='pt').to(device)
        emb, _, _, scores = raw(enc['input_ids'], enc.get('attention_mask'))
        scores = scores[0].cpu().tolist()
        for k,s in enumerate(scores):
            if len(activations[k]) < 30:  # retain limited examples per anchor
                activations[k].append((s,a[:120]))
    with open(REPORT_TXT,'w',encoding='utf-8') as f_txt, open(REPORT_CSV,'w',newline='',encoding='utf-8') as f_csv:
        writer = csv.writer(f_csv); writer.writerow(['anchor','score','text'])
        for anchor, items in activations.items():
            items.sort(key=lambda x: x[0], reverse=True)
            f_txt.write(f"\n==== ANCHOR {anchor} ===\n")
            for s,t in items[:10]:
                f_txt.write(f"{s:.3f} | {t}\n"); writer.writerow([anchor, f"{s:.3f}", t])
    print('Saved anchor reports:', REPORT_TXT, REPORT_CSV)

analyze_anchors()

EXPORT_PATH = f"{CHECKPOINT_DIR}/nexus_64anchors_final.pt"
raw_to_save = raw._orig_mod if hasattr(raw,'_orig_mod') else raw
torch.save({'model_state_dict': raw_to_save.state_dict(), 'config': {'base_model':'microsoft/mpnet-base','nsa_anchors':64,'hash_dim':256,'embedding_dim':768,'matryoshka_dims':DIMS}, 'training_steps': step}, EXPORT_PATH)
print('Final model exported ->', EXPORT_PATH)
# Out:
# Anchors: 100%|██████████| 800/800 [00:08<00:00, 94.42it/s]
# Saved anchor reports: /content/drive/MyDrive/nexus_checkpoints_64anchors/anchor_analysis.txt /content/drive/MyDrive/nexus_checkpoints_64anchors/anchor_top.csv
# Final model exported -> /content/drive/MyDrive/nexus_checkpoints_64anchors/nexus_64anchors_final.pt

# %% [markdown]
# # Task
# Analyze the behavior and reactions of the model by performing a more in-depth test using a larger sample of the dataset.

# %% [markdown]
# ## Generate embeddings for a larger dataset sample
#
# ### Subtask:
# Select a larger random sample from the dataset and generate embeddings and anchor scores for each text in the sample.

# %% [markdown]
# **Reasoning**:
# Select a larger sample of the dataset, generate embeddings and anchor scores for both sentences in each pair from the sample, and store them for analysis.

# %% [markdown]
# **Reasoning**:
# Calculate the mean and standard deviation of anchor scores for both sentence A and sentence B samples across all anchors, and then visualize the distributions.

# %% [markdown]
# ## Identify top activating examples per anchor
#
# ### Subtask:
# For each anchor, identify the top examples that cause the highest activation scores.

# %% [markdown]
# **Reasoning**:
# Initialize the dictionary to store top examples for each anchor and then iterate through the sampled data to populate it.

# %% [markdown]
# ## Qualitative analysis of top examples
#
# ### Subtask:
# Manually review the top examples for a subset of anchors to understand what kind of text content or semantic features each anchor is specializing in.

# %% [markdown]
# **Reasoning**:
# Manually review the top examples for a subset of anchors to understand their specialization. I will select a few anchors based on the previous analysis of mean and standard deviation of anchor scores and print their top examples for manual inspection.

# %% [markdown]
# ## Visualize anchor relationships
#
# ### Subtask:
# If possible, visualize the relationships between anchors based on their co-activation patterns or the similarity of the embeddings they are most sensitive to. This could involve techniques like t-SNE or UMAP on anchor vectors or the embeddings of highly activating texts.

# %% [markdown]
# **Reasoning**:
# Calculate the pairwise cosine similarity between the anchor vectors and then use t-SNE to reduce the dimensionality for visualization.

# %% [markdown]
# ## Summarize findings
#
# ### Subtask:
# Summarize the findings from the quantitative analysis of anchor activation distribution and the qualitative analysis of top examples to provide insights into the model's behavior and anchor specialization.

# %% [markdown]
# **Reasoning**:
# Summarize the findings from the quantitative and qualitative analyses and the t-SNE visualization to provide insights into the model's behavior and anchor specialization.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The mean anchor scores for both sentence A and sentence B samples varied significantly across anchors, ranging from approximately -2.2 to 2.4 for sentence A and -2.3 to 2.5 for sentence B.
# *   The standard deviation of anchor scores for individual anchors across the sampled texts was generally lower than the mean scores, ranging from approximately 0.2 to 0.98.
# *   Qualitative analysis of top examples suggested that Anchor 30 might be sensitive to political or controversial content, Anchor 1 to more general or neutral content, and Anchor 53 to informal/conversational language or technical vocabulary.
# *   The t-SNE visualization of anchor vectors suggests potential relationships or clustering among anchors based on their representation in the model's learned space.
#
# ### Insights or Next Steps
#
# *   The combination of quantitative and qualitative analysis provides initial hypotheses about anchor functions, which could be further explored through more extensive manual review or automated text analysis of top examples.
# *   Investigating the clusters observed in the t-SNE visualization could reveal groups of anchors that collectively represent specific types of semantic information.

# %% [markdown]
# # Task
# Suggest ways to improve the model's performance based on the training results and analysis.

# %% [markdown]
# ## Explore additional training data
#
# ### Subtask:
# Identify and potentially integrate other relevant datasets for training, such as other NLI datasets (e.g., ANLI) or datasets focused on specific domains or tasks relevant to the intended use of the model.

# %% [markdown]
# **Reasoning**:
# Outline a plan for integrating other relevant datasets and discuss potential challenges.

# %% [markdown]
# ## Hyperparameter tuning
#
# ### Subtask:
# Experiment with different hyperparameters for training, such as learning rates, batch sizes, weight decay, temperature for InfoNCE loss, or the weights of different loss components (main, topic, hash, spec).

# %% [markdown]
# **Reasoning**:
# Modify the `STEP 4` code cell to include easily adjustable hyperparameters and run a training loop with these parameters.

# %% [markdown]
# **Reasoning**:
# Run evaluation with the current hyperparameters to assess performance and then modify the hyperparameters in the `HYPERPARAMS` dictionary and re-run the training and evaluation cells to experiment with different settings as requested by the subtask.

# %% [markdown]
# ## Architecture modifications
#
# ### Subtask:
# Consider minor modifications to the model architecture, such as adding more layers to the projection heads, trying different activation functions, or experimenting with different base models if appropriate.

# %% [markdown]
# **Reasoning**:
# Review the current model architecture and propose a minor modification to the projection heads by adding an additional linear layer with ReLU activation.
